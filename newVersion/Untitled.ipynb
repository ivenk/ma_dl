# %%
from facenet_pytorch import MTCNN, InceptionResnetV1
import torch
from torch.utils.data import DataLoader
from torchvision import datasets
import numpy as np
import pandas as pd
import os

workers = 0 if os.name == 'nt' else 4
dtype = torch.cuda.FloatTensor

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cuda:0

# %%
mtcnn = MTCNN(
    image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device
)

# %%
resnet = InceptionResnetV1(pretrained='casia-webface').eval().to(device)
# Out:
# Downloading parameters (1/2)
# Downloading parameters (2/2)

# %%
def collate_fn(x):
    return x[0]

dataset = datasets.ImageFolder('../../../data/small_data/train')
dataset.idx_to_class = {i:c for c, i in dataset.class_to_idx.items()}
loader = DataLoader(dataset, collate_fn=collate_fn, num_workers=workers)

# %%
aligned = []
names = []
for x, y in loader:
    x_aligned, prob = mtcnn(x, return_prob=True)
    if x_aligned is not None:
        print('Face detected with probability: {:8f}'.format(prob))
        aligned.append(x_aligned)
        names.append(dataset.idx_to_class[y])
# Out:
# Face detected with probability: 0.999904
# Face detected with probability: 0.999998
# Face detected with probability: 0.999993
# Face detected with probability: 0.999950
# Face detected with probability: 0.999990
# Face detected with probability: 0.999200
# Face detected with probability: 0.999220
# Face detected with probability: 0.999859
# Face detected with probability: 0.999829
# Face detected with probability: 0.990638
# Face detected with probability: 0.999998
# Face detected with probability: 0.999989
# Face detected with probability: 0.999358
# Face detected with probability: 0.999988
# Face detected with probability: 0.999991
# Face detected with probability: 0.999769
# Face detected with probability: 0.999997
# Face detected with probability: 0.999973
# Face detected with probability: 0.999812
# Face detected with probability: 1.000000
# Face detected with probability: 0.999832
# Face detected with probability: 0.984941
# Face detected with probability: 0.999976
# Face detected with probability: 0.999994
# Face detected with probability: 0.999737
# Face detected with probability: 0.999971
# Face detected with probability: 0.999964
# Face detected with probability: 0.999998
# Face detected with probability: 0.999992
# Face detected with probability: 0.999999
# Face detected with probability: 0.999978
# Face detected with probability: 0.999996
# Face detected with probability: 1.000000
# Face detected with probability: 0.999757
# Face detected with probability: 0.999872
# Face detected with probability: 0.999990
# Face detected with probability: 0.999928
# Face detected with probability: 0.999998
# Face detected with probability: 1.000000
# Face detected with probability: 0.999980
# Face detected with probability: 0.999999
# Face detected with probability: 0.999991
# Face detected with probability: 0.999708
# Face detected with probability: 0.999664
# Face detected with probability: 0.997610
# Face detected with probability: 0.999306
# Face detected with probability: 0.999997
# Face detected with probability: 0.999718
# Face detected with probability: 0.999994
# Face detected with probability: 0.999972
# Face detected with probability: 0.999165
# Face detected with probability: 0.999992
# Face detected with probability: 0.999997
# Face detected with probability: 0.999992
# Face detected with probability: 0.999972
# Face detected with probability: 0.999999
# Face detected with probability: 0.999994
# Face detected with probability: 0.999624
# Face detected with probability: 0.999942
# Face detected with probability: 0.999992
# Face detected with probability: 0.999951
# Face detected with probability: 0.999999
# Face detected with probability: 0.999998
# Face detected with probability: 0.999900
# Face detected with probability: 0.999988
# Face detected with probability: 0.999968
# Face detected with probability: 0.999997
# Face detected with probability: 0.999224
# Face detected with probability: 0.999996
# Face detected with probability: 0.998188
# Face detected with probability: 0.999820
# Face detected with probability: 0.999866
# Face detected with probability: 1.000000
# Face detected with probability: 0.999961
# Face detected with probability: 0.999711
# Face detected with probability: 0.999835
# Face detected with probability: 0.999670
# Face detected with probability: 1.000000
# Face detected with probability: 0.999887
# Face detected with probability: 0.999928
# Face detected with probability: 0.999980
# Face detected with probability: 0.999966
# Face detected with probability: 0.999986
# Face detected with probability: 0.999997
# Face detected with probability: 0.999999
# Face detected with probability: 0.999882
# Face detected with probability: 0.999990
# Face detected with probability: 0.999964
# Face detected with probability: 0.999965
# Face detected with probability: 0.999997
# Face detected with probability: 0.998843
# Face detected with probability: 0.999973
# Face detected with probability: 0.999957
# Face detected with probability: 0.999987
# Face detected with probability: 0.999589
# Face detected with probability: 0.998401
# Face detected with probability: 0.999995
# Face detected with probability: 0.998479
# Face detected with probability: 0.999844
# Face detected with probability: 0.999996
# Face detected with probability: 0.999565
# Face detected with probability: 0.999935
# Face detected with probability: 0.999991
# Face detected with probability: 0.999992
# Face detected with probability: 0.999997
# Face detected with probability: 0.999936
# Face detected with probability: 0.999999
# Face detected with probability: 0.999859
# Face detected with probability: 0.999991
# Face detected with probability: 0.999749
# Face detected with probability: 0.999995
# Face detected with probability: 0.999999
# Face detected with probability: 0.999999
# Face detected with probability: 0.999919
# Face detected with probability: 0.999863
# Face detected with probability: 0.999998
# Face detected with probability: 0.999950
# Face detected with probability: 0.999997
# Face detected with probability: 0.993033
# Face detected with probability: 0.999835
# Face detected with probability: 0.999771
# Face detected with probability: 0.999896
# Face detected with probability: 0.995419
# Face detected with probability: 0.999816
# Face detected with probability: 0.999879
# Face detected with probability: 0.999990
# Face detected with probability: 0.999991
# Face detected with probability: 0.999981
# Face detected with probability: 0.999517
# Face detected with probability: 0.989108
# Face detected with probability: 0.999997
# Face detected with probability: 0.999957
# Face detected with probability: 0.999468
# Face detected with probability: 0.999936
# Face detected with probability: 0.999134
# Face detected with probability: 0.999973
# Face detected with probability: 0.999944
# Face detected with probability: 0.999984
# Face detected with probability: 0.999975
# Face detected with probability: 0.999879
# Face detected with probability: 0.999451
# Face detected with probability: 0.999788
# Face detected with probability: 0.999650
# Face detected with probability: 0.999726
# Face detected with probability: 0.999994
# Face detected with probability: 0.999959
# Face detected with probability: 0.999995
# Face detected with probability: 0.999766
# Face detected with probability: 0.999953
# Face detected with probability: 0.999902
# Face detected with probability: 0.999234
# Face detected with probability: 0.999451
# Face detected with probability: 0.999907
# Face detected with probability: 0.999681
# Face detected with probability: 0.999362
# Face detected with probability: 0.999610
# Face detected with probability: 0.999665
# Face detected with probability: 0.998303
# Face detected with probability: 0.997831
# Face detected with probability: 0.999992
# Face detected with probability: 0.999592
# Face detected with probability: 0.999460
# Face detected with probability: 0.999454
# Face detected with probability: 0.999776
# Face detected with probability: 0.999998
# Face detected with probability: 0.998745
# Face detected with probability: 0.996919
# Face detected with probability: 0.997902
# Face detected with probability: 0.998788
# Face detected with probability: 0.999177
# Face detected with probability: 0.998610
# Face detected with probability: 0.999782
# Face detected with probability: 0.999133
# Face detected with probability: 0.997071
# Face detected with probability: 0.999931
# Face detected with probability: 0.999981
# Face detected with probability: 0.998336
# Face detected with probability: 1.000000
# Face detected with probability: 0.999406
# Face detected with probability: 0.999989
# Face detected with probability: 0.999972
# Face detected with probability: 0.999988
# Face detected with probability: 0.999243
# Face detected with probability: 0.999983
# Face detected with probability: 1.000000
# Face detected with probability: 0.999790
# Face detected with probability: 0.999958
# Face detected with probability: 0.999976
# Face detected with probability: 0.999997
# Face detected with probability: 0.999997
# Face detected with probability: 0.999986
# Face detected with probability: 0.999995
# Face detected with probability: 0.999990
# Face detected with probability: 1.000000
# Face detected with probability: 1.000000
# Face detected with probability: 0.999998
# Face detected with probability: 0.999998
# Face detected with probability: 0.999639
# Face detected with probability: 0.999993
# Face detected with probability: 0.997915
# Face detected with probability: 0.999991
# Face detected with probability: 0.998919
# Face detected with probability: 0.999963
# Face detected with probability: 0.999490
# Face detected with probability: 0.999994
# Face detected with probability: 0.999997
# Face detected with probability: 0.999993
# Face detected with probability: 0.999989
# Face detected with probability: 0.999890
# Face detected with probability: 0.999940
# Face detected with probability: 0.999920
# Face detected with probability: 0.999999
# Face detected with probability: 0.999999
# Face detected with probability: 0.999992
# Face detected with probability: 0.999829
# Face detected with probability: 0.999993
# Face detected with probability: 0.999985
# Face detected with probability: 0.998102
# Face detected with probability: 0.999985
# Face detected with probability: 0.999988
# Face detected with probability: 0.999987
# Face detected with probability: 0.999974
# Face detected with probability: 0.999989
# Face detected with probability: 0.999784
# Face detected with probability: 0.999993
# Face detected with probability: 0.999911
# Face detected with probability: 0.999405
# Face detected with probability: 0.999599
# Face detected with probability: 0.998216
# Face detected with probability: 0.999768
# Face detected with probability: 0.999983
# Face detected with probability: 0.999973
# Face detected with probability: 0.999987
# Face detected with probability: 0.999895
# Face detected with probability: 0.999966
# Face detected with probability: 0.999986
# Face detected with probability: 0.999888
# Face detected with probability: 0.999941
# Face detected with probability: 0.999486
# Face detected with probability: 0.999661
# Face detected with probability: 0.998064
# Face detected with probability: 0.992019
# Face detected with probability: 0.999878
# Face detected with probability: 0.999941
# Face detected with probability: 0.998969
# Face detected with probability: 0.999133
# Face detected with probability: 0.999883
# Face detected with probability: 0.999939
# Face detected with probability: 0.999883
# Face detected with probability: 0.999961
# Face detected with probability: 0.999890
# Face detected with probability: 0.999903
# Face detected with probability: 0.998880
# Face detected with probability: 0.999981
# Face detected with probability: 0.999545
# Face detected with probability: 0.999560
# Face detected with probability: 0.998961
# Face detected with probability: 0.993356
# Face detected with probability: 0.999995
# Face detected with probability: 0.999950
# Face detected with probability: 0.997318
# Face detected with probability: 0.999955
# Face detected with probability: 0.999869
# Face detected with probability: 0.998745
# Face detected with probability: 0.999624
# Face detected with probability: 0.982542
# Face detected with probability: 0.999754
# Face detected with probability: 0.995865
# Face detected with probability: 0.999925
# Face detected with probability: 0.999953
# Face detected with probability: 0.999972
# Face detected with probability: 0.999993
# Face detected with probability: 0.999603
# Face detected with probability: 0.999904
# Face detected with probability: 0.999617
# Face detected with probability: 0.999983
# Face detected with probability: 0.999925
# Face detected with probability: 0.999973
# Face detected with probability: 0.998792
# Face detected with probability: 0.999997
# Face detected with probability: 0.999792
# Face detected with probability: 0.997618
# Face detected with probability: 0.999867
# Face detected with probability: 0.995284
# Face detected with probability: 0.999820
# Face detected with probability: 0.999834
# Face detected with probability: 0.985051
# Face detected with probability: 0.999012
# Face detected with probability: 0.988669
# Face detected with probability: 0.999994
# Face detected with probability: 0.999904
# Face detected with probability: 0.999965
# Face detected with probability: 0.999971
# Face detected with probability: 0.999997
# Face detected with probability: 0.999957
# Face detected with probability: 0.999462
# Face detected with probability: 0.999960
# Face detected with probability: 1.000000
# Face detected with probability: 0.999787
# Face detected with probability: 0.999996
# Face detected with probability: 0.999785
# Face detected with probability: 0.999755
# Face detected with probability: 0.999989
# Face detected with probability: 0.999995
# Face detected with probability: 0.999913
# Face detected with probability: 1.000000
# Face detected with probability: 0.999949
# Face detected with probability: 0.999997
# Face detected with probability: 0.999994
# Face detected with probability: 0.999909
# Face detected with probability: 0.999987
# Face detected with probability: 0.999973
# Face detected with probability: 0.999696
# Face detected with probability: 0.999950
# Face detected with probability: 0.999945
# Face detected with probability: 0.999973
# Face detected with probability: 0.999970
# Face detected with probability: 0.999980
# Face detected with probability: 0.999991
# Face detected with probability: 0.999998
# Face detected with probability: 0.999955
# Face detected with probability: 1.000000
# Face detected with probability: 0.999437
# Face detected with probability: 1.000000
# Face detected with probability: 0.999924
# Face detected with probability: 0.999855
# Face detected with probability: 0.999992
# Face detected with probability: 0.999941
# Face detected with probability: 0.843116
# Face detected with probability: 0.999816
# Face detected with probability: 0.999784
# Face detected with probability: 1.000000
# Face detected with probability: 0.999999
# Face detected with probability: 0.999948
# Face detected with probability: 0.999999
# Face detected with probability: 0.999943
# Face detected with probability: 0.997110
# Face detected with probability: 0.999884
# Face detected with probability: 0.999925
# Face detected with probability: 0.999992
# Face detected with probability: 0.999989
# Face detected with probability: 0.999997
# Face detected with probability: 0.999999
# Face detected with probability: 0.999586
# Face detected with probability: 0.999840
# Face detected with probability: 0.999626
# Face detected with probability: 0.992720
# Face detected with probability: 0.999960
# Face detected with probability: 0.999991
# Face detected with probability: 0.999921
# Face detected with probability: 0.999988
# Face detected with probability: 0.999572
# Face detected with probability: 0.999129
# Face detected with probability: 0.999979
# Face detected with probability: 0.999999
# Face detected with probability: 0.999876
# Face detected with probability: 1.000000
# Face detected with probability: 0.999945
# Face detected with probability: 0.999987
# Face detected with probability: 0.995238
# Face detected with probability: 0.998717
# Face detected with probability: 0.999971
# Face detected with probability: 0.999969
# Face detected with probability: 0.999999
# Face detected with probability: 0.999991
# Face detected with probability: 0.999826

# %%
aligned = torch.stack(aligned).to(device)
embeddings = resnet(aligned).detach().cpu()
embeddings.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-6b0cb715fa62> in <module>
# ----> 1 aligned = torch.stack(aligned).to(device)
#       2 aligned.shape
#       3 embeddings = resnet(aligned).detach().cpu()
#       4 embeddings.shape
#
# TypeError: stack(): argument 'tensors' (position 1) must be tuple of Tensors, not Tensor
