# %% [markdown]
# # Small dataset test
#
# 80/20 test/valid
# 8 bit output

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
import numpy as np
import pandas as pd
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import Dataset, DataLoader
from skimage import io, transform
from PIL import Image

# %%
class MultiClass(nn.Sequential):
    def __init__(self, input_dim=512, hidden_layers=5, output_dim=8):
        super(MultiClass, self).__init__()
        self.l1 = nn.Linear(input_dim, 200)
        self.l2 = nn.Linear(200, 50)
        self.l5 = nn.Linear(50, output_dim)

    def forward(self, x):
        x = F.relu(self.l1(x))
        x = F.relu(self.l2(x))
        x = self.l5(x)
        return torch.sigmoid(x)

# %%
model = MultiClass()

# %% [markdown]
# # load data

# %%
scaler = transforms.Resize((224, 224))
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
to_tensor = transforms.ToTensor()

# %%
transform = transforms.Compose([
    scaler, 
    to_tensor,
    normalize
])

# %%
train_ds = datasets.ImageFolder('../../data/data/train', transform=transform)
train_ds.idx_to_class = {i:c for c, i in train_ds.class_to_idx.items()}
train_dl = DataLoader(train_ds)

valid_ds = datasets.ImageFolder('../../data/data/valid', transform=transform)
valid_ds.idx_to_class = {i:c for c, i in valid_ds.class_to_idx.items()}
valid_dl = DataLoader(valid_ds)

# %%
loss_func = nn.BCELoss() #MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, weight_decay=1e-5) #weight_decay=1e-4

# %% [markdown]
# # Preparation stuff

# %%
def get_vector(img):
    # 2. Create a PyTorch Variable with the transformed image
    t_img = Variable(img)  
    
    # 3. Create a vector of zeros that will hold our feature vector
    #    The 'avgpool' layer has an output size of 512
    my_embedding = torch.zeros(512)    

    # 4. Define a function that will copy the output of a layer
    def copy_data(m, i, o):
      my_embedding.copy_(o.data.squeeze())    
    
    # 5. Attach that function to our selected layer
    h = layer.register_forward_hook(copy_data)    
    # 6. Run the model on our transformed image
    resnet(t_img)    
    # 7. Detach our copy function from the layer
    h.remove()    
    # 8. Return the feature vector
    return my_embedding

# %%
from torch.autograd import Variable

# %%
# Load the pretrained model
resnet = models.resnet18(pretrained=True)
# Use the model object to select the desired layer
layer = resnet._modules.get('avgpool')
resnet.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
def calculate_mistakes(pred, target):
    mistakes = 0
    
    if len(pred) != len(target):
        raise Exception('sizes of both tensors must match')
        
    for x,y in zip(pred, target):
        if round(x.item()) != y.item():
            mistakes = mistakes + 1
        
    return mistakes

# %%
epochs = 200
for e in range(epochs):
    print("======================")
    print("Epoch : " + str(e))
    epoch_loss = 0
    epoch_mistakes = 0
    train_size = len(train_dl)
    
    for index, (data, target) in enumerate(train_dl):
#       (data, target) = train_ds[0]
 #       data_t   = get_vector(data.unsqueeze(0))
        data_t   = get_vector(data)

        target_t = torch.FloatTensor([int(x) for x in train_ds.idx_to_class[target[0].item()]])
#        target_t = torch.FloatTensor([int(x) for x in train_ds.idx_to_class[target]])
#        print(target_t)
        data_v   = Variable(data_t, requires_grad=False)
        target_v = Variable(target_t, requires_grad=False)

        model.train()
        # forward
        pred = model.forward(data_v)
#       print(pred)
        # zero grads
        optimizer.zero_grad()
        # calculate loss
        loss = loss_func(pred, target_v.float())
        epoch_loss = epoch_loss + loss
        # back prop
        loss.backward()
        optimizer.step()
        
        epoch_mistakes = epoch_mistakes + calculate_mistakes(pred, target_t)
        
    print("Train loss : " + str(epoch_loss.item()))
    print("Average errors : " + str(epoch_mistakes/train_size))
    
    valid_loss = 0
    valid_mistakes = 0
    valid_size = len(valid_dl)
    for index, (data, target) in enumerate(valid_dl):
        data_t   = get_vector(data)
        target_t = torch.FloatTensor([int(x) for x in valid_ds.idx_to_class[target[0].item()]])
        
        data_v   = Variable(data_t, requires_grad=False)
        target_v = Variable(target_t, requires_grad=False)

        model.eval()
        pred = model.forward(data_v)
        loss = loss_func(pred, target_v.float())
        valid_loss = valid_loss + loss
        valid_mistakes = valid_mistakes + calculate_mistakes(pred, target_t)
        
        
    print("Valid loss : " + str(valid_loss.item()))
    print("Average valid errors : " + str(valid_mistakes/valid_size))
# Out:
# ======================
# Epoch : 0
# Train loss : 1.3031402826309204
# Average errors : 0.0
# Valid loss : 25.37374496459961
# Average valid errors : 0.6666666666666666
# ======================
# Epoch : 1
# Train loss : 1.2896476984024048
# Average errors : 0.0
# Valid loss : 25.117565155029297
# Average valid errors : 0.6666666666666666
# ======================
# Epoch : 2
# Train loss : 1.2737983465194702
# Average errors : 0.0
# Valid loss : 24.890724182128906
# Average valid errors : 0.6428571428571429
# ======================
# Epoch : 3
# Train loss : 1.2592787742614746
# Average errors : 0.0
# Valid loss : 24.68507957458496
# Average valid errors : 0.6428571428571429
# ======================
# Epoch : 4
# Train loss : 1.2436729669570923
# Average errors : 0.0
# Valid loss : 24.397872924804688
# Average valid errors : 0.6428571428571429
# ======================
# Epoch : 5
# Train loss : 1.2306008338928223
# Average errors : 0.0
# Valid loss : 24.2072696685791
# Average valid errors : 0.6190476190476191
# ======================
# Epoch : 6
# Train loss : 1.2154653072357178
# Average errors : 0.0
# Valid loss : 23.973176956176758
# Average valid errors : 0.6190476190476191
# ======================
# Epoch : 7
# Train loss : 1.2015600204467773
# Average errors : 0.0
# Valid loss : 23.735807418823242
# Average valid errors : 0.6190476190476191
# ======================
# Epoch : 8
# Train loss : 1.1881681680679321
# Average errors : 0.0
# Valid loss : 23.494346618652344
# Average valid errors : 0.6190476190476191
# ======================
# Epoch : 9
# Train loss : 1.1729044914245605
# Average errors : 0.0
# Valid loss : 21.823333740234375
# Average valid errors : 0.6190476190476191
# ======================
# Epoch : 10
# Train loss : 1.1603667736053467
# Average errors : 0.0
# Valid loss : 21.586034774780273
# Average valid errors : 0.5952380952380952
# ======================
# Epoch : 11
# Train loss : 1.1497477293014526
# Average errors : 0.0
# Valid loss : 21.40241241455078
# Average valid errors : 0.5952380952380952
# ======================
# Epoch : 12
# Train loss : 1.1347153186798096
# Average errors : 0.0
# Valid loss : 21.15630340576172
# Average valid errors : 0.5952380952380952
# ======================
# Epoch : 13
# Train loss : 1.1229864358901978
# Average errors : 0.0
# Valid loss : 20.94420623779297
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 14
# Train loss : 1.1096272468566895
# Average errors : 0.0
# Valid loss : 19.269725799560547
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 15
# Train loss : 1.0980072021484375
# Average errors : 0.0
# Valid loss : 18.98775863647461
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 16
# Train loss : 1.0836725234985352
# Average errors : 0.0
# Valid loss : 18.82384490966797
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 17
# Train loss : 1.0726139545440674
# Average errors : 0.0
# Valid loss : 18.59661293029785
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 18
# Train loss : 1.0605008602142334
# Average errors : 0.0
# Valid loss : 18.277658462524414
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 19
# Train loss : 1.0461019277572632
# Average errors : 0.0
# Valid loss : 18.04960060119629
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 20
# Train loss : 1.0372945070266724
# Average errors : 0.0
# Valid loss : 17.829681396484375
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 21
# Train loss : 1.025432825088501
# Average errors : 0.0
# Valid loss : 17.60931968688965
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 22
# Train loss : 1.0137795209884644
# Average errors : 0.0
# Valid loss : 17.32574462890625
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 23
# Train loss : 1.0009106397628784
# Average errors : 0.0
# Valid loss : 17.089492797851562
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 24
# Train loss : 0.9913738369941711
# Average errors : 0.0
# Valid loss : 16.867189407348633
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 25
# Train loss : 0.9808719158172607
# Average errors : 0.0
# Valid loss : 16.618221282958984
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 26
# Train loss : 0.9688774347305298
# Average errors : 0.0
# Valid loss : 16.330657958984375
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 27
# Train loss : 0.957672655582428
# Average errors : 0.0
# Valid loss : 16.111236572265625
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 28
# Train loss : 0.9472885727882385
# Average errors : 0.0
# Valid loss : 15.912675857543945
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 29
# Train loss : 0.936474621295929
# Average errors : 0.0
# Valid loss : 15.638784408569336
# Average valid errors : 0.5714285714285714
# ======================
# Epoch : 30
# Train loss : 0.9257522225379944
# Average errors : 0.0
# Valid loss : 15.425537109375
# Average valid errors : 0.5476190476190477
# ======================
# Epoch : 31
# Train loss : 0.915249228477478
# Average errors : 0.0
# Valid loss : 15.175322532653809
# Average valid errors : 0.5238095238095238
# ======================
# Epoch : 32
# Train loss : 0.9050447940826416
# Average errors : 0.0
# Valid loss : 14.970532417297363
# Average valid errors : 0.5
# ======================
# Epoch : 33
# Train loss : 0.8948767781257629
# Average errors : 0.0
# Valid loss : 14.736261367797852
# Average valid errors : 0.5
# ======================
# Epoch : 34
# Train loss : 0.8836334943771362
# Average errors : 0.0
# Valid loss : 14.491960525512695
# Average valid errors : 0.47619047619047616
# ======================
# Epoch : 35
# Train loss : 0.8752450942993164
# Average errors : 0.0
# Valid loss : 14.295692443847656
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 36
# Train loss : 0.8640512824058533
# Average errors : 0.0
# Valid loss : 14.045652389526367
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 37
# Train loss : 0.8559364676475525
# Average errors : 0.0
# Valid loss : 13.868669509887695
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 38
# Train loss : 0.8454291224479675
# Average errors : 0.0
# Valid loss : 13.634564399719238
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 39
# Train loss : 0.8375548124313354
# Average errors : 0.0
# Valid loss : 13.428049087524414
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 40
# Train loss : 0.8271531462669373
# Average errors : 0.0
# Valid loss : 13.189125061035156
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 41
# Train loss : 0.8177513480186462
# Average errors : 0.0
# Valid loss : 12.988460540771484
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 42
# Train loss : 0.8078839182853699
# Average errors : 0.0
# Valid loss : 12.799641609191895
# Average valid errors : 0.4523809523809524
# ======================
# Epoch : 43
# Train loss : 0.8010231256484985
# Average errors : 0.0
# Valid loss : 12.61104965209961
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 44
# Train loss : 0.7905596494674683
# Average errors : 0.0
# Valid loss : 12.413142204284668
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 45
# Train loss : 0.782879114151001
# Average errors : 0.0
# Valid loss : 12.278477668762207
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 46
# Train loss : 0.7729728817939758
# Average errors : 0.0
# Valid loss : 12.087885856628418
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 47
# Train loss : 0.7666252851486206
# Average errors : 0.0
# Valid loss : 11.890120506286621
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 48
# Train loss : 0.7573304176330566
# Average errors : 0.0
# Valid loss : 11.73257827758789
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 49
# Train loss : 0.7489389181137085
# Average errors : 0.0
# Valid loss : 11.568217277526855
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 50
# Train loss : 0.7415215969085693
# Average errors : 0.0
# Valid loss : 11.378260612487793
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 51
# Train loss : 0.7329941987991333
# Average errors : 0.0
# Valid loss : 11.191407203674316
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 52
# Train loss : 0.7261268496513367
# Average errors : 0.0
# Valid loss : 11.014018058776855
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 53
# Train loss : 0.7182888984680176
# Average errors : 0.0
# Valid loss : 10.857799530029297
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 54
# Train loss : 0.7094358801841736
# Average errors : 0.0
# Valid loss : 10.664923667907715
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 55
# Train loss : 0.7039264440536499
# Average errors : 0.0
# Valid loss : 10.505197525024414
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 56
# Train loss : 0.6942527294158936
# Average errors : 0.0
# Valid loss : 10.345281600952148
# Average valid errors : 0.40476190476190477
# ======================
# Epoch : 57
# Train loss : 0.6885957717895508
# Average errors : 0.0
# Valid loss : 10.16828441619873
# Average valid errors : 0.38095238095238093
# ======================
# Epoch : 58
# Train loss : 0.6811754107475281
# Average errors : 0.0
# Valid loss : 10.005951881408691
# Average valid errors : 0.38095238095238093
# ======================
# Epoch : 59
# Train loss : 0.6740930080413818
# Average errors : 0.0
# Valid loss : 9.840494155883789
# Average valid errors : 0.38095238095238093
# ======================
# Epoch : 60
# Train loss : 0.6676264405250549
# Average errors : 0.0
# Valid loss : 9.68272590637207
# Average valid errors : 0.38095238095238093
# ======================
# Epoch : 61
# Train loss : 0.6605342030525208
# Average errors : 0.0
# Valid loss : 9.523259162902832
# Average valid errors : 0.38095238095238093
# ======================
# Epoch : 62
# Train loss : 0.6542065143585205
# Average errors : 0.0
# Valid loss : 9.370556831359863
# Average valid errors : 0.3333333333333333
# ======================
# Epoch : 63
# Train loss : 0.6472722887992859
# Average errors : 0.0
# Valid loss : 9.192268371582031
# Average valid errors : 0.3333333333333333
# ======================
# Epoch : 64
# Train loss : 0.6413792371749878
# Average errors : 0.0
# Valid loss : 9.06573486328125
# Average valid errors : 0.3333333333333333
# ======================
# Epoch : 65
# Train loss : 0.6338837742805481
# Average errors : 0.0
# Valid loss : 8.893756866455078
# Average valid errors : 0.30952380952380953
# ======================
# Epoch : 66
# Train loss : 0.627907931804657
# Average errors : 0.0
# Valid loss : 8.749656677246094
# Average valid errors : 0.30952380952380953
# ======================
# Epoch : 67
# Train loss : 0.6206631660461426
# Average errors : 0.0
# Valid loss : 8.577630996704102
# Average valid errors : 0.30952380952380953
# ======================
# Epoch : 68
# Train loss : 0.6150637269020081
# Average errors : 0.0
# Valid loss : 8.454546928405762
# Average valid errors : 0.30952380952380953
# ======================
# Epoch : 69
# Train loss : 0.6094638705253601
# Average errors : 0.0
# Valid loss : 8.281164169311523
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 70
# Train loss : 0.6025384068489075
# Average errors : 0.0
# Valid loss : 8.138516426086426
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 71
# Train loss : 0.5978747606277466
# Average errors : 0.0
# Valid loss : 7.988680362701416
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 72
# Train loss : 0.590691864490509
# Average errors : 0.0
# Valid loss : 7.807653903961182
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 73
# Train loss : 0.5853496789932251
# Average errors : 0.0
# Valid loss : 7.695390224456787
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 74
# Train loss : 0.5802432298660278
# Average errors : 0.0
# Valid loss : 7.556371688842773
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 75
# Train loss : 0.5743255019187927
# Average errors : 0.0
# Valid loss : 7.406104564666748
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 76
# Train loss : 0.5683539509773254
# Average errors : 0.0
# Valid loss : 7.248031139373779
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 77
# Train loss : 0.5633158087730408
# Average errors : 0.0
# Valid loss : 7.098108768463135
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 78
# Train loss : 0.5580238103866577
# Average errors : 0.0
# Valid loss : 6.974289417266846
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 79
# Train loss : 0.5526816248893738
# Average errors : 0.0
# Valid loss : 6.824246883392334
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 80
# Train loss : 0.5465566515922546
# Average errors : 0.0
# Valid loss : 6.688999176025391
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 81
# Train loss : 0.5428711771965027
# Average errors : 0.0
# Valid loss : 6.5755510330200195
# Average valid errors : 0.2857142857142857
# ======================
# Epoch : 82
# Train loss : 0.5368844270706177
# Average errors : 0.0
# Valid loss : 6.425591945648193
# Average valid errors : 0.2619047619047619
# ======================
# Epoch : 83
# Train loss : 0.5322339534759521
# Average errors : 0.0
# Valid loss : 6.3048577308654785
# Average valid errors : 0.2619047619047619
# ======================
# Epoch : 84
# Train loss : 0.5270176529884338
# Average errors : 0.0
# Valid loss : 6.1774725914001465
# Average valid errors : 0.2619047619047619
# ======================
# Epoch : 85
# Train loss : 0.522697925567627
# Average errors : 0.0
# Valid loss : 6.0761823654174805
# Average valid errors : 0.2619047619047619
# ======================
# Epoch : 86
# Train loss : 0.5173865556716919
# Average errors : 0.0
# Valid loss : 5.944355487823486
# Average valid errors : 0.2619047619047619
# ======================
# Epoch : 87
# Train loss : 0.512805163860321
# Average errors : 0.0
# Valid loss : 5.822203636169434
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 88
# Train loss : 0.5078004598617554
# Average errors : 0.0
# Valid loss : 5.711925029754639
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 89
# Train loss : 0.5033206343650818
# Average errors : 0.0
# Valid loss : 5.5979485511779785
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 90
# Train loss : 0.49950483441352844
# Average errors : 0.0
# Valid loss : 5.503993988037109
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 91
# Train loss : 0.4947257339954376
# Average errors : 0.0
# Valid loss : 5.386375904083252
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 92
# Train loss : 0.48989421129226685
# Average errors : 0.0
# Valid loss : 5.272406578063965
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 93
# Train loss : 0.48650795221328735
# Average errors : 0.0
# Valid loss : 5.184197902679443
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 94
# Train loss : 0.4812324345111847
# Average errors : 0.0
# Valid loss : 5.0658392906188965
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 95
# Train loss : 0.47779494524002075
# Average errors : 0.0
# Valid loss : 4.976800918579102
# Average valid errors : 0.23809523809523808
# ======================
# Epoch : 96
# Train loss : 0.47389790415763855
# Average errors : 0.0
# Valid loss : 4.876940727233887
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 97
# Train loss : 0.4690285325050354
# Average errors : 0.0
# Valid loss : 4.780707359313965
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 98
# Train loss : 0.46584171056747437
# Average errors : 0.0
# Valid loss : 4.659668922424316
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 99
# Train loss : 0.4613370895385742
# Average errors : 0.0
# Valid loss : 4.576899528503418
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 100
# Train loss : 0.45772701501846313
# Average errors : 0.0
# Valid loss : 4.471290111541748
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 101
# Train loss : 0.45422494411468506
# Average errors : 0.0
# Valid loss : 4.374459266662598
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 102
# Train loss : 0.4496705234050751
# Average errors : 0.0
# Valid loss : 4.290706634521484
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 103
# Train loss : 0.4467158317565918
# Average errors : 0.0
# Valid loss : 4.187131881713867
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 104
# Train loss : 0.44242677092552185
# Average errors : 0.0
# Valid loss : 4.101163864135742
# Average valid errors : 0.21428571428571427
# ======================
# Epoch : 105
# Train loss : 0.43906480073928833
# Average errors : 0.0
# Valid loss : 4.018866062164307
# Average valid errors : 0.19047619047619047
# ======================
# Epoch : 106
# Train loss : 0.43523314595222473
# Average errors : 0.0
# Valid loss : 3.9256768226623535
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 107
# Train loss : 0.43197008967399597
# Average errors : 0.0
# Valid loss : 3.8363325595855713
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 108
# Train loss : 0.42813947796821594
# Average errors : 0.0
# Valid loss : 3.7411060333251953
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 109
# Train loss : 0.42475295066833496
# Average errors : 0.0
# Valid loss : 3.6705164909362793
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 110
# Train loss : 0.4217234253883362
# Average errors : 0.0
# Valid loss : 3.573173999786377
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 111
# Train loss : 0.4177309572696686
# Average errors : 0.0
# Valid loss : 3.4945409297943115
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 112
# Train loss : 0.41464728116989136
# Average errors : 0.0
# Valid loss : 3.413877487182617
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 113
# Train loss : 0.4116450250148773
# Average errors : 0.0
# Valid loss : 3.3242499828338623
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 114
# Train loss : 0.40812528133392334
# Average errors : 0.0
# Valid loss : 3.245375394821167
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 115
# Train loss : 0.40481066703796387
# Average errors : 0.0
# Valid loss : 3.160466194152832
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 116
# Train loss : 0.40182334184646606
# Average errors : 0.0
# Valid loss : 3.091170072555542
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 117
# Train loss : 0.3987813889980316
# Average errors : 0.0
# Valid loss : 3.016371011734009
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 118
# Train loss : 0.395293265581131
# Average errors : 0.0
# Valid loss : 2.9345076084136963
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 119
# Train loss : 0.3921826183795929
# Average errors : 0.0
# Valid loss : 2.86788010597229
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 120
# Train loss : 0.38903138041496277
# Average errors : 0.0
# Valid loss : 2.7759361267089844
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 121
# Train loss : 0.38626614212989807
# Average errors : 0.0
# Valid loss : 2.720487117767334
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 122
# Train loss : 0.3831665515899658
# Average errors : 0.0
# Valid loss : 2.645521640777588
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 123
# Train loss : 0.38070592284202576
# Average errors : 0.0
# Valid loss : 2.561659097671509
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 124
# Train loss : 0.37749120593070984
# Average errors : 0.0
# Valid loss : 2.4901256561279297
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 125
# Train loss : 0.3746297359466553
# Average errors : 0.0
# Valid loss : 2.4193673133850098
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 126
# Train loss : 0.3719838261604309
# Average errors : 0.0
# Valid loss : 2.3385119438171387
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 127
# Train loss : 0.3689516484737396
# Average errors : 0.0
# Valid loss : 2.279268741607666
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 128
# Train loss : 0.36622461676597595
# Average errors : 0.0
# Valid loss : 2.1966207027435303
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 129
# Train loss : 0.36370372772216797
# Average errors : 0.0
# Valid loss : 2.133758068084717
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 130
# Train loss : 0.36027657985687256
# Average errors : 0.0
# Valid loss : 2.0651867389678955
# Average valid errors : 0.16666666666666666
# ======================
# Epoch : 131
# Train loss : 0.35788846015930176
# Average errors : 0.0
# Valid loss : 1.9884268045425415
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 132
# Train loss : 0.3548238277435303
# Average errors : 0.0
# Valid loss : 1.922076940536499
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 133
# Train loss : 0.35247480869293213
# Average errors : 0.0
# Valid loss : 1.8561331033706665
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 134
# Train loss : 0.34920966625213623
# Average errors : 0.0
# Valid loss : 1.7912334203720093
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 135
# Train loss : 0.3467247784137726
# Average errors : 0.0
# Valid loss : 1.711043357849121
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 136
# Train loss : 0.3438612222671509
# Average errors : 0.0
# Valid loss : 1.6512014865875244
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 137
# Train loss : 0.3412867486476898
# Average errors : 0.0
# Valid loss : 1.5867912769317627
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 138
# Train loss : 0.33873265981674194
# Average errors : 0.0
# Valid loss : 1.5253889560699463
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 139
# Train loss : 0.336436003446579
# Average errors : 0.0
# Valid loss : 1.4604544639587402
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 140
# Train loss : 0.3337007462978363
# Average errors : 0.0
# Valid loss : 1.3930401802062988
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 141
# Train loss : 0.33114102482795715
# Average errors : 0.0
# Valid loss : 1.3380975723266602
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 142
# Train loss : 0.32893869280815125
# Average errors : 0.0
# Valid loss : 1.2819949388504028
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 143
# Train loss : 0.3261362314224243
# Average errors : 0.0
# Valid loss : 1.2223896980285645
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 144
# Train loss : 0.32349032163619995
# Average errors : 0.0
# Valid loss : 1.1638699769973755
# Average valid errors : 0.14285714285714285
# ======================
# Epoch : 145
# Train loss : 0.3213687539100647
# Average errors : 0.0
# Valid loss : 1.1135708093643188
# Average valid errors : 0.11904761904761904
# ======================
# Epoch : 146
# Train loss : 0.318787544965744
# Average errors : 0.0
# Valid loss : 1.0593901872634888
# Average valid errors : 0.11904761904761904
# ======================
# Epoch : 147
# Train loss : 0.31671565771102905
# Average errors : 0.0
# Valid loss : 1.0040078163146973
# Average valid errors : 0.11904761904761904
# ======================
# Epoch : 148
# Train loss : 0.3140849471092224
# Average errors : 0.0
# Valid loss : 0.9569684863090515
# Average valid errors : 0.11904761904761904
# ======================
# Epoch : 149
# Train loss : 0.31151509284973145
# Average errors : 0.0
# Valid loss : 0.9049814343452454
# Average valid errors : 0.11904761904761904
# ======================
# Epoch : 150
# Train loss : 0.30944934487342834
# Average errors : 0.0
# Valid loss : 0.8577851057052612
# Average valid errors : 0.11904761904761904
# ======================
# Epoch : 151
# Train loss : 0.30687034130096436
# Average errors : 0.0
# Valid loss : 0.8129839897155762
# Average valid errors : 0.11904761904761904
# ======================
# Epoch : 152
# Train loss : 0.30446431040763855
# Average errors : 0.0
# Valid loss : 0.7619956731796265
# Average valid errors : 0.09523809523809523
# ======================
# Epoch : 153
# Train loss : 0.3024638593196869
# Average errors : 0.0
# Valid loss : 0.7258664965629578
# Average valid errors : 0.07142857142857142
# ======================
# Epoch : 154
# Train loss : 0.2999982237815857
# Average errors : 0.0
# Valid loss : 0.678357720375061
# Average valid errors : 0.07142857142857142
# ======================
# Epoch : 155
# Train loss : 0.29805833101272583
# Average errors : 0.0
# Valid loss : 0.6449808478355408
# Average valid errors : 0.07142857142857142
# ======================
# Epoch : 156
# Train loss : 0.2955707013607025
# Average errors : 0.0
# Valid loss : 0.6030085682868958
# Average valid errors : 0.07142857142857142
# ======================
# Epoch : 157
# Train loss : 0.29309532046318054
# Average errors : 0.0
# Valid loss : 0.5654130578041077
# Average valid errors : 0.07142857142857142
# ======================
# Epoch : 158
# Train loss : 0.29085153341293335
# Average errors : 0.0
# Valid loss : 0.5317625999450684
# Average valid errors : 0.047619047619047616
# ======================
# Epoch : 159
# Train loss : 0.2888283431529999
# Average errors : 0.0
# Valid loss : 0.503480076789856
# Average valid errors : 0.023809523809523808
# ======================
# Epoch : 160
# Train loss : 0.2864471971988678
# Average errors : 0.0
# Valid loss : 0.4686799943447113
# Average valid errors : 0.023809523809523808
# ======================
# Epoch : 161
# Train loss : 0.2844966948032379
# Average errors : 0.0
# Valid loss : 0.43938133120536804
# Average valid errors : 0.023809523809523808
# ======================
# Epoch : 162
# Train loss : 0.2818111479282379
# Average errors : 0.0
# Valid loss : 0.413305401802063
# Average valid errors : 0.023809523809523808
# ======================
# Epoch : 163
# Train loss : 0.2800811231136322
# Average errors : 0.0
# Valid loss : 0.38542044162750244
# Average valid errors : 0.0
# ======================
# Epoch : 164
# Train loss : 0.277715802192688
# Average errors : 0.0
# Valid loss : 0.36022207140922546
# Average valid errors : 0.0
# ======================
# Epoch : 165
# Train loss : 0.2756432294845581
# Average errors : 0.0
# Valid loss : 0.33648771047592163
# Average valid errors : 0.0
# ======================
# Epoch : 166
# Train loss : 0.2732647657394409
# Average errors : 0.0
# Valid loss : 0.3164357841014862
# Average valid errors : 0.0
# ======================
# Epoch : 167
# Train loss : 0.2711729407310486
# Average errors : 0.0
# Valid loss : 0.2965714633464813
# Average valid errors : 0.0
# ======================
# Epoch : 168
# Train loss : 0.26935532689094543
# Average errors : 0.0
# Valid loss : 0.2773793339729309
# Average valid errors : 0.0
# ======================
# Epoch : 169
# Train loss : 0.26697883009910583
# Average errors : 0.0
# Valid loss : 0.25924187898635864
# Average valid errors : 0.0
# ======================
# Epoch : 170
# Train loss : 0.26512467861175537
# Average errors : 0.0
# Valid loss : 0.24329303205013275
# Average valid errors : 0.0
# ======================
# Epoch : 171
# Train loss : 0.26321423053741455
# Average errors : 0.0
# Valid loss : 0.22909465432167053
# Average valid errors : 0.0
# ======================
# Epoch : 172
# Train loss : 0.26115119457244873
# Average errors : 0.0
# Valid loss : 0.21326427161693573
# Average valid errors : 0.0
# ======================
# Epoch : 173
# Train loss : 0.2592427730560303
# Average errors : 0.0
# Valid loss : 0.20074768364429474
# Average valid errors : 0.0
# ======================
# Epoch : 174
# Train loss : 0.2570415735244751
# Average errors : 0.0
# Valid loss : 0.18806283175945282
# Average valid errors : 0.0
# ======================
# Epoch : 175
# Train loss : 0.2556283175945282
# Average errors : 0.0
# Valid loss : 0.17783555388450623
# Average valid errors : 0.0
# ======================
# Epoch : 176
# Train loss : 0.2535407245159149
# Average errors : 0.0
# Valid loss : 0.166659414768219
# Average valid errors : 0.0
# ======================
# Epoch : 177
# Train loss : 0.25127431750297546
# Average errors : 0.0
# Valid loss : 0.15609270334243774
# Average valid errors : 0.0
# ======================
# Epoch : 178
# Train loss : 0.24969685077667236
# Average errors : 0.0
# Valid loss : 0.14683276414871216
# Average valid errors : 0.0
# ======================
# Epoch : 179
# Train loss : 0.24767328798770905
# Average errors : 0.0
# Valid loss : 0.13817869126796722
# Average valid errors : 0.0
# ======================
# Epoch : 180
# Train loss : 0.24616888165473938
# Average errors : 0.0
# Valid loss : 0.13093872368335724
# Average valid errors : 0.0
# ======================
# Epoch : 181
# Train loss : 0.24394644796848297
# Average errors : 0.0
# Valid loss : 0.12368704378604889
# Average valid errors : 0.0
# ======================
# Epoch : 182
# Train loss : 0.24194397032260895
# Average errors : 0.0
# Valid loss : 0.11641273647546768
# Average valid errors : 0.0
# ======================
# Epoch : 183
# Train loss : 0.24034465849399567
# Average errors : 0.0
# Valid loss : 0.11013776063919067
# Average valid errors : 0.0
# ======================
# Epoch : 184
# Train loss : 0.2386784851551056
# Average errors : 0.0
# Valid loss : 0.1046208068728447
# Average valid errors : 0.0
# ======================
# Epoch : 185
# Train loss : 0.23663541674613953
# Average errors : 0.0
# Valid loss : 0.09951027482748032
# Average valid errors : 0.0
# ======================
# Epoch : 186
# Train loss : 0.2348143309354782
# Average errors : 0.0
# Valid loss : 0.09391661733388901
# Average valid errors : 0.0
# ======================
# Epoch : 187
# Train loss : 0.233161062002182
# Average errors : 0.0
# Valid loss : 0.08943529427051544
# Average valid errors : 0.0
# ======================
# Epoch : 188
# Train loss : 0.23140273988246918
# Average errors : 0.0
# Valid loss : 0.08536384999752045
# Average valid errors : 0.0
# ======================
# Epoch : 189
# Train loss : 0.2297815978527069
# Average errors : 0.0
# Valid loss : 0.08125042915344238
# Average valid errors : 0.0
# ======================
# Epoch : 190
# Train loss : 0.22802668809890747
# Average errors : 0.0
# Valid loss : 0.0776115208864212
# Average valid errors : 0.0
# ======================
# Epoch : 191
# Train loss : 0.22627413272857666
# Average errors : 0.0
# Valid loss : 0.07343021035194397
# Average valid errors : 0.0
# ======================
# Epoch : 192
# Train loss : 0.22479680180549622
# Average errors : 0.0
# Valid loss : 0.07052955776453018
# Average valid errors : 0.0
# ======================
# Epoch : 193
# Train loss : 0.2230272740125656
# Average errors : 0.0
# Valid loss : 0.06744146347045898
# Average valid errors : 0.0
# ======================
# Epoch : 194
# Train loss : 0.22118057310581207
# Average errors : 0.0
# Valid loss : 0.06421360373497009
# Average valid errors : 0.0
# ======================
# Epoch : 195
# Train loss : 0.2195444107055664
# Average errors : 0.0
# Valid loss : 0.06169911473989487
# Average valid errors : 0.0
# ======================
# Epoch : 196
# Train loss : 0.21811485290527344
# Average errors : 0.0
# Valid loss : 0.05928315967321396
# Average valid errors : 0.0
# ======================
# Epoch : 197
# Train loss : 0.21624496579170227
# Average errors : 0.0
# Valid loss : 0.05696995183825493
# Average valid errors : 0.0
# ======================
# Epoch : 198
# Train loss : 0.2148444950580597
# Average errors : 0.0
# Valid loss : 0.05460425466299057
# Average valid errors : 0.0
# ======================
# Epoch : 199
# Train loss : 0.21299579739570618
# Average errors : 0.0
# Valid loss : 0.052408307790756226
# Average valid errors : 0.0

# %%
torch.save(model.state_dict(), 'small_v2_400.pt')
